# %% [markdown]
# ### Lack of Robustness of the Markowitz Procedure, and the GMW

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import risk_tools as rt

# %%
ind = rt.get_ind_returns()
er = rt.annualized_rets(ind['1996':'2000'], 12)
cov = ind['1996':'2000'].cov()

# %%
bonds_10y = 2.0450
riskfree_rate = 0.1
l = ['Food', 'Steel']

rt.max_sharp_ratio(riskfree_rate, er[l], cov.loc[l, l])
# Out:
# array([0.75040362, 0.24959638])

# %%
er[l]
# Out:
# Food     0.116799
# Steel    0.115809
# dtype: float64

# %%
rt.max_sharp_ratio(riskfree_rate, np.array([.11, .12]), cov.loc[l, l])
# Out:
# array([0.57930354, 0.42069646])

# %%
rt.max_sharp_ratio(riskfree_rate, np.array([.13, .10]), cov.loc[l, l])
# Out:
# array([1., 0.])

# %%
rt.plot_ef(20, er, cov, show_cml=True, riskfree_rate=0.1)
# Out:
# <AxesSubplot:xlabel='Volatility'>

# %%
rt.plot_ef(20, er, cov, show_cml=True, riskfree_rate=0.1, show_ew=True)
# Out:
# <AxesSubplot:xlabel='Volatility'>

# %%
rt.plot_ef(20, er, cov, show_cml=True, riskfree_rate=0.1, show_ew=True, show_gmv=True)
# Out:
# <AxesSubplot:xlabel='Volatility'>
