# %% [markdown]
# ### Interctive Polotting and Monte Carlo simulations of CPPI

# %%
import ipywidgets as widgets
from IPython.display import display
import pandas as pd
import risk_tools as rt

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### GBM Interactive Plotts

# %%
rt.gbm(10, 100, mu=0.1).plot(legend=False)
# Out:
# <AxesSubplot:>

# %%
rt.show_gbm(30, 0.07, 0.15)

# %%
gbm_controls = widgets.interactive(rt.show_gbm,
                                    n_scenarios=(1, 20, 5),
                                    mu=(0, 0.2, 0.01),
                                    sigma=(0, 0.3, 0.01))

# %% [markdown]
# ### Interactive CCPI Simulation - Monte Carlo

# %%
cppi_controls = widgets.interactive(rt.show_cppi,
                                    n_scenarios=widgets.IntSlider(
                                        min=1, max=1000, step=5, value=50),
                                    mu=(0., .2, .01),
                                    sigma=(0, .30, .15),
                                    floor=(0, 2, .1),
                                    m=(1, 5, .5),
                                    riskfree_rate=(0, .05, .01),
                                    y_max=widgets.IntSlider(min=0, max=100, step=1, value=100, description='Zoom Y Axis'))

display(cppi_controls)
# Out:
# interactive(children=(IntSlider(value=50, description='n_scenarios', max=1000, min=1, step=5), FloatSlider(val…
