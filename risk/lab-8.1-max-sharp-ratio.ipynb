# %%
import pandas as pd
import numpy as np
import risk_tools as rt

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
ind = rt.get_ind_returns()
er = rt.annualized_rets(ind['1996':'2000'], 12)
cov = ind['1996':'2000'].cov()

# %%
bonds_10y = 2.0450 / 100

rt.plot_ef(20, er, cov, show_cml=True, riskfree_rate=bonds_10y)
# Out:
# <AxesSubplot:xlabel='Volatility'>

# %%
portfolio = rt.max_sharp_ratio(bonds_10y, er, cov)
portfolio
# Out:
# array([3.78275772e-14, 0.00000000e+00, 1.03765848e-13, 0.00000000e+00,
#        5.52592980e-14, 1.55978847e-14, 0.00000000e+00, 3.03761721e-01,
#        1.66977409e-14, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 5.27936839e-02, 0.00000000e+00, 9.70612756e-14,
#        0.00000000e+00, 6.77929465e-02, 1.04713479e-13, 3.25785475e-01,
#        0.00000000e+00, 0.00000000e+00, 7.36810102e-02, 2.76675843e-14,
#        0.00000000e+00, 1.70922121e-14, 1.76185163e-01, 2.01770362e-15,
#        3.91049956e-15, 0.00000000e+00])
