# %% [markdown]
# # Commodities
# - Aluminum (Al)
# - Coal
# - Copper (Cu)
# - Corn
# - Crude Oil
# - Gold (Au)
# - Lead (Pb)
# - Natural Gas
# - Nickel (Ni)
# - Palladium (Pd)
# - Platinum (Pl)
# - Silver (Ag)
# - Wheat
# - Zinc (Zn)

# %%
import pandas as pd
import monitor_kit as mk
import datetime as dt

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Gold

# %%
gold = mk.load_data(name='Gold', ticker='GC=F', end=dt.datetime.now(), years=20)
gold_close = gold['Close']
gold_close.plot.line()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Silver

# %%
silver = mk.load_data(name='Silver', ticker='SI=F',
                      end=dt.datetime.now(), years=20)
silver = silver['Close']
silver.plot.line()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Natural Gas

# %%
natural_gas = mk.load_data(name='Natural Gas', ticker='NG=F',
                      end=dt.datetime.now(), years=20)
natural_gas = natural_gas['Close']
natural_gas.plot.line()
# Out:
# <AxesSubplot:xlabel='Date'>
