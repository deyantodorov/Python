# %%
import tabula

# %%
doc = tabula.io.read_pdf('01-03-2022.pdf', pages=1)[0].dropna()

# %%
doc.columns = doc.iloc[0]
doc = doc.iloc[1:doc.shape[0] - 1]

# %%
doc.head()
# Out:
# 1 No Служба по вписванията Продажби Дарения Замени Ограничени\rвещни права  \
# 2  1            СВ - Айтос      288      72     11                       5
# 3  2           СВ - Ардино       14       4      0                       2
# 4  3       СВ - Асеновград      470      87      6                      14
# 5  4           СВ - Балчик      272      26      2                       6
# 6  5      СВ - Белоградчик      136      15      9                       4
#
# 1 Наеми Аренди Законни ипотеки Договорни\rипотеки  ... Делби КНА АДС  АОС  \
# 2    39    113               5                 14  ...     8  88   4  107
# 3     1      0               0                  2  ...     0  11   3   45
# 4    11     14              12                 43  ...    25  73   4   61
# 5     9     44              11                 22  ...    16  38   1   37
# 6    96     71               0                  4  ...     3  27   2   16
#
# 1 Други актове Общо вписвания Заличени искови\rмолби Заличени\rвъзбрани  \
# 2           42            856                      0                 30
# 3           11             99                      0                  4
# 4           61           1014                      0                 68
# 5           29            659                      1                 83
# 6           23            427                      0                 15
#
# 1 Заличени\rипотеки Стари актове
# 2                18            0
# 3                 3            0
# 4                38            0
# 5                46            0
# 6                 3            0
#
# [5 rows x 23 columns]

# %%
doc[['Служба по вписванията', 'Продажби']]
# Out:
# 1   Служба по вписванията Продажби
# 2              СВ - Айтос      288
# 3             СВ - Ардино       14
# 4         СВ - Асеновград      470
# 5             СВ - Балчик      272
# 6        СВ - Белоградчик      136
# ..                    ...      ...
# 110         СВ - Чепеларе       89
# 111      СВ - Червен бряг      184
# 112           СВ - Чирпан      228
# 113            СВ - Шумен      578
# 114            СВ - Ямбол      679
#
# [113 rows x 2 columns]
