# %%
import tabula

# %%
doc = tabula.io.read_pdf('01-03-2022.pdf', pages=1)[0].dropna()
doc.head()
# Out:
#   Агенция по вписванията\rСПРАВКА ОТНОСНО БРОЯ ВПИСВАНИЯ ПО ПЕРСОНАЛНА И РЕАЛНА СИСТЕМА\rза Първо тримесечие, 2022 година  \
# 1                                                 No
# 2                                                  1
# 3                                                  2
# 4                                                  3
# 5                                                  4
#
#               Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 1  Служба по вписванията   Продажби    Дарения     Замени
# 2             СВ - Айтос        288         72         11
# 3            СВ - Ардино         14          4          0
# 4        СВ - Асеновград        470         87          6
# 5            СВ - Балчик        272         26          2
#
#                 Unnamed: 4 Unnamed: 5 Unnamed: 6       Unnamed: 7  \
# 1  Ограничени\rвещни права      Наеми     Аренди  Законни ипотеки
# 2                        5         39        113                5
# ...

# %%
doc.columns = doc.iloc[0]

# %%
doc.head()
# Out:
# 9    8     СВ - Ботевград   286   44   5  10    5    3    9   34  ...   9  \
# 9    8     СВ - Ботевград   286   44   5  10    5    3    9   34  ...   9
# 10   9       СВ - Брезник    77   10   6   1   19    9    0    2  ...   1
# 11  10        СВ - Бургас  1679  216  23  47   14   13  128  366  ...  32
# 12  11          СВ - Бяла   264   81   1  12  305   44    1   12  ...   8
# 13  12  СВ - Бяла Слатина   232   25   1   4   97  242    0    1  ...   6
#
# 9    41   6  231   37   798   0   41   52  0
# 9    41   6  231   37   798   0   41   52  0
# 10   57   1  278   19   504   0    5    4  0
# 11  135  17  551  208  3844  13  269  392  0
# 12   45   5  149   42  1045   0   60    9  0
# 13   63   0  232   25   968   0   20   16  0
#
# [5 rows x 23 columns]
